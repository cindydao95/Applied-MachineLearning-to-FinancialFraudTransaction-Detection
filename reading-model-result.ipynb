# %%
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
result = pd.read_json("ML_report.json")

# %%
macro_f1_validation_fold =  [np.mean(result[i]["macro_f1_folds"]) for i in result]

# %%
macro_f1_validation_fold
# Out:
# [0.7322473523849897,
#  0.8612989375492909,
#  0.8655974386433691,
#  0.8608634496616233,
#  0.4329185944789028]

# %%
accuracy_test = result.loc["accuracy_test",:]
macro_f1_test = result.loc["macro_f1_test",:]
recall_score_test = result.loc["recall_score_test",:]
precision_score_test = result.loc["precision_score_test",:]
running_time_mins = result.loc["running_time_(min)",:]
running_time_hous = result.loc["running_time_(hours)",:]

# %%
model_name = list(result.keys())

# %%
model_name
# Out:
# ['LR', 'RF', 'KNN', 'DT', 'gaussian']

# %%
result_df = pd.DataFrame(data = {"model":model_name, "macro_f1_validation_fold":macro_f1_validation_fold, "accuracy_test": accuracy_test,
"macro_f1_test":macro_f1_test, "recall_score_test":recall_score_test, "precision_score_test":precision_score_test, "running_time_mins":running_time_mins,"running_time_hous":running_time_hous})

# %%
print(result_df)
# Out:
#              model  macro_f1_validation_fold accuracy_test macro_f1_test  \
# LR              LR                  0.732247      0.780115       0.77982
# RF              RF                  0.861299      0.780074       0.77834
# KNN            KNN                  0.865597      0.769744       0.76846
# DT              DT                  0.860863      0.780324      0.778486
# gaussian  gaussian                  0.432919       0.54582      0.432537
#
#          recall_score_test precision_score_test running_time_mins  \
# LR                0.780115             0.781625        794m 32.2s
# RF                0.780074              0.78912        847m 19.4s
# KNN               0.769744             0.775863        2323m 5.2s
# DT                0.780324             0.789946          962m 20s
# gaussian           0.54582             0.727419         1011m 40s
#
#          running_time_hous
# LR                13 hours
# RF                14 hours
# KNN               38 hours
# DT                16 hours
# gaussian       16.85 hours

# %%
for column in result_df.columns[1:]:
    plt.bar(result_df["model"],result_df[column])
    plt.title(column)
    plt.show()
